# %% [markdown]
# # K3.1 MAIN Archived Analysis
#
# This notebook is a placeholder for local inspection of the archived K3.1 headline results. The full GPU Colab training run is not rerun here.

# %%
from pathlib import Path
import pandas as pd

root = Path('..')
results = pd.read_csv(root / 'results' / 'k3_1_main_results.csv')
summary = pd.read_csv(root / 'results' / 'k3_1_main_summary.csv')
results, summary
