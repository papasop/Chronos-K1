# %% [markdown]
# # Chronos-K1 Colab: Exp7 Only\nThis notebook only runs `experiment_7_metric_controlled_normalization.py`.

# %%
# !git clone https://github.com/papasop/Chronos-K1.git || true\n%cd /content/Chronos-K1/k1-manifold-core\n!git fetch origin\n!git reset --hard origin/main\n!python -m pip install -q --upgrade pip\n!python -m pip install -q -r requirements-benchmarks.txt\n

# %%
# Smoke test (pipeline only, not final statistics)\n!python3 benchmarks/experiment_7_metric_controlled_normalization.py --smoke\nprint("Smoke test completed. For README-level statistics, run full config (no --smoke), preferably on CUDA.")

# %%
# Full run (N=30, EPOCHS=12)\n# !python3 benchmarks/experiment_7_metric_controlled_normalization.py
