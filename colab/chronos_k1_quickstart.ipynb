# %% [markdown]
# # Chronos-K1 Quickstart (5-minute)\nInstall, run two core theory demos, then run Exp7 metric-prior evidence.

# %%
# Cell 1: install\n!git clone https://github.com/papasop/Chronos-K1.git\n%cd Chronos-K1/k1-manifold-core\n!python -m pip install -q -r requirements-benchmarks.txt

# %%
# Cell 2: demo_02 causal cone\n!python examples/demo_02_causal_cone.py

# %%
# Cell 3: demo_04 recovery scaling (slope ~ -2)\n!python examples/demo_04_recovery_scaling.py

# %%
# Cell 4: Exp7 Metric Prior evidence\n!python benchmarks/experiment_7_metric_controlled_normalization.py --smoke\n!python - <<'PY'\nimport pandas as pd\np='results/experiment_7_metric_controlled_normalization/experiment_7_metric_dataset_interaction.csv'\nprint(pd.read_csv(p))\nPY

# %% [markdown]
# ## Cell 5: conclusion\n- Lorentz signature and causal cone are explicit and visualized.\n- Law III null-flow scaling shows slope close to -2 in log-log space.\n- Exp7 reports metric-sensitive interaction evidence for Lorentz normalization.
